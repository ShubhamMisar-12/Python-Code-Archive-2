# %%
import pandas as pd
df_studentexamscores = df_ex3 = pd.read_csv('df_studentexamscores.csv')
df_students = pd.read_csv('df_students.csv')

# %%
df_studentexamscores
# Out:
#      StudentID    Exam  Score
# 0            1   exam7     61
# 1            1   exam9     38
# 2            1   exam3     85
# 3            1   exam7     70
# 4            1   exam5     44
# ..         ...     ...    ...
# 579         99   exam4     60
# 580         99  exam10     48
# 581         99   exam4     55
# 582         99   exam7     75
# 583        100   exam8     82
#
# [584 rows x 3 columns]

# %%
df_students
# Out:
#     StudentID First_Name  Last_Name         Degree
# 0           1     Pamela  Rodriguez       graduate
# 1           2    Kristie    Jackson  undergraduate
# 2           3     George     Curtis       graduate
# 3           4   Christie      Casey  undergraduate
# 4           5      Emily      Yoder  undergraduate
# ..        ...        ...        ...            ...
# 95         96   Benjamin       Dyer  undergraduate
# 96         97      Jason    Delgado  undergraduate
# 97         98    Kenneth     Cortez  undergraduate
# 98         99  Elizabeth      Short  undergraduate
# 99        100     Robert    Andrade  undergraduate
#
# [100 rows x 4 columns]

# %%
df3 = pd.merge(df_studentexamscores, df_students, on = 'StudentID').groupby(['Degree']).mean().round(2).reset_index()
df3.drop(['StudentID'], axis = 1)
# Out:
#           Degree  Score
# 0       graduate  62.50
# 1  undergraduate  61.63

# %%
df5 = pd.merge(df_studentexamscores, df_students, on = 'StudentID').groupby(['StudentID']).mean().round(2).reset_index()
df_sort = df5.sort_values(by = 'Score', ascending = False)
df_sort = df_sort.rename(columns = {'Score': 'average'})
df6 = pd.merge(df_sort, df_students, on = 'StudentID')
df6.loc[0:9,['First_Name', 'Last_Name', 'Degree','average']]
# Out:
#   First_Name   Last_Name         Degree  average
# 0       John  Washington       graduate    83.00
# 1     Robert     Andrade  undergraduate    82.00
# 2       Paul       Smith  undergraduate    79.00
# 3      Jason     Delgado  undergraduate    77.50
# 4     Calvin       Perez  undergraduate    75.00
# 5      Jason    Thompson       graduate    75.00
# 6     Calvin    Martinez  undergraduate    74.50
# 7      Billy      Palmer  undergraduate    74.38
# 8    Matthew        King  undergraduate    73.56
# 9      Debra       Pratt  undergraduate    72.60

# %%
df = pd.merge(df_studentexamscores, df_students, on = 'StudentID').groupby(['Degree']).mean().round(2).reset_index()
df = df.rename(columns = {'Score': 'Average'})
df = df.drop(['StudentID'], axis = 1)
df = df.set_index('Degree')
df
# Out:
#                Average
# Degree
# graduate         62.50
# undergraduate    61.63

# %%
df_ex4 = pd.read_csv('ex4.csv')
from pandas.testing import assert_frame_equal
assert_frame_equal(df, df_ex4)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26580\1136603028.py in <module>
#       1 df_ex4 = pd.read_csv('ex4.csv')
#       2 from pandas.testing import assert_frame_equal
# ----> 3 assert_frame_equal(df, df_ex4)
#
#     [... skipping hidden 1 frame]
#
# ~\anaconda3\lib\site-packages\pandas\_testing\asserters.py in raise_assert_detail(obj, message, left, right, diff, index_values)
#     680         msg += f"\n[diff]: {diff}"
#     681
# --> 682     raise AssertionError(msg)
#     683
#     684
#
# AssertionError: DataFrame are different
#
# DataFrame shape mismatch
# [left]:  (2, 1)
# [right]: (2, 2)

# %%
df = pd.merge(df_studentexamscores, df_students, on = 'StudentID').groupby(['Degree']).mean().round(2)
df = df.rename(columns = {'Score': 'Average'})
df['Average'].to_frame()
# df["Average"].astype("int32")
# df[['Degree', 'Average'] ]
# Out:
#                Average
# Degree
# graduate         62.50
# undergraduate    61.63

# %%
import sqlite3
import numpy as np
import pandas as pd
from faker import Faker

# %%
np.random.seed(0)
fake = Faker()
Faker.seed(0)
first_name = []
last_name = []
user_name = []
for _ in range(100):
    name = fake.name().split(" ")
    num = str(np.random.randint(1000,9999))
    first_name.append(name[0])
    last_name.append(''.join(name[1:]))
    u_name = name[0].lower()[0:2]+num
    #print(u_name)
    user_name.append(u_name)
    #print([np.random.randint(1000,9999) for i in range(4)])

dic = {'username' : user_name, 'first_name': first_name , 'last_name': last_name}
df4 = pd.DataFrame.from_dict(dic)
df4
# Out:
#    username first_name   last_name
# 0    no3732      Norma      Fisher
# 1    jo4264      Jorge    Sullivan
# 2    el5859  Elizabeth       Woods
# 3    su8891      Susan      Wagner
# 4    pe5373      Peter  Montgomery
# ..      ...        ...         ...
# 95   te7922      Terry       Wells
# 96   va5182    Vanessa      Cooper
# 97   mi1307    Michael     Simmons
# 98   ni6302   Nicholas       Kline
# 99   lo2152       Lori     Bennett
#
# [100 rows x 3 columns]

# %%
np.random.seed(0)

# Define the means and standard deviations for the homework and exam scores
mu = [35, 75, 25, 45, 45, 75, 25, 45, 35]
sigma = [9, 15, 7, 10, 5, 20, 8, 9, 10]
max_score = [50, 100, 40, 60, 50, 100, 50, 60, 50]

# Generate the scores using a normal distribution
scores = np.random.normal(mu, sigma, size = (max(max_score),len(mu)))
scores = np.round(scores)
scores_clip = np.clip(scores,0,max_score)
lst = scores_clip.T
lst

# # Create a pandas dataframe with the scores
# df = pd.DataFrame(scores, columns=['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5', 'Exam1', 'Exam2', 'Exam3', 'Exam4'])

# # Return the dataframe
# df
# Out:
# array([[ 50.,  39.,  38.,  33.,  46.,  31.,  35.,  19.,  45.,  43.,  31.,
#          39.,  50.,  34.,  31.,  41.,  50.,  28.,  44.,  38.,  32.,  49.,
#          50.,  28.,  35.,  36.,  25.,  32.,  36.,  30.,  39.,  50.,  41.,
#          40.,  23.,  36.,  25.,  24.,  29.,  22.,  41.,  25.,  33.,  22.,
#          43.,  38.,  50.,  36.,  43.,  25.,  26.,  35.,  14.,  27.,  49.,
#          34.,  32.,  17.,  20.,  39.,  37.,  29.,  23.,  41.,  28.,  31.,
#          38.,  37.,  40.,  32.,  29.,  47.,  30.,  23.,  35.,  39.,  29.,
#          19.,  28.,  41.,  32.,  40.,  34.,  41.,  41.,  25.,  32.,  23.,
#          27.,  42.,  30.,  35.,  47.,  32.,  42.,  31.,  37.,  27.,  36.,
#          39.],
#        [ 81.,  77.,  62.,  98.,  93.,  56.,  81.,  78.,  56.,  82.,  93.,
#         100.,  97.,  84., 100.,  84.,  89.,  74.,  76.,  88.,  54.,  56.,
#          95.,  79.,  81.,  77.,  87.,  70.,  70.,  66.,  33.,  73.,  95.,
# ...

# %%
dic = {'Hw1' : lst[0] ,'Hw2': lst[1],'Hw3': lst[2], 'Hw4': lst[3], 'Hw5': lst[4], 'Exam1': lst[5], 'Exam2': lst[6], 'Exam3':lst[7] , 'Exam4': lst[8]}
df2 = pd.DataFrame.from_dict(dic)
df2
# Out:
#      Hw1   Hw2   Hw3   Hw4   Hw5  Exam1  Exam2  Exam3  Exam4
# 0   50.0  81.0  32.0  60.0  50.0   55.0   33.0   44.0   34.0
# 1   39.0  77.0  35.0  53.0  46.0   84.0   28.0   58.0   33.0
# 2   38.0  62.0   7.0  52.0  49.0   60.0   43.0   32.0   35.0
# 3   33.0  98.0  35.0  47.0  47.0   57.0    9.0   42.0   37.0
# 4   46.0  93.0  22.0  42.0  40.0   47.0   11.0   60.0   30.0
# ..   ...   ...   ...   ...   ...    ...    ...    ...    ...
# 95  31.0  50.0  22.0  40.0  45.0   98.0   26.0   45.0   36.0
# 96  37.0  60.0  24.0  48.0  38.0   92.0   34.0   39.0   33.0
# 97  27.0  85.0  18.0  43.0  41.0   76.0   11.0   57.0   25.0
# 98  36.0  72.0  20.0  36.0  50.0   64.0   27.0   38.0   29.0
# 99  39.0  89.0  24.0  31.0  50.0   58.0   13.0   60.0   31.0
#
# [100 rows x 9 columns]

# %%
df_des = df2.describe().T.drop(['count','min','25%','50%','75%','max'], axis = 1).round(2)
df_des['mean_theoretical'] = mu
df_des['std_theoretical'] = sigma
df_des['abs_mean_diff'] = abs(df_des['mean'] - df_des['mean_theoretical']).round(2)
df_des['abs_std_diff'] = abs(df_des['std'] - df_des['std_theoretical']).round(2)
df_des
# Out:
#         mean    std  mean_theoretical  std_theoretical  abs_mean_diff  \
# Hw1    34.45   8.38                35                9           0.55
# Hw2    74.60  14.96                75               15           0.40
# Hw3    24.94   6.51                25                7           0.06
# Hw4    44.71   9.58                45               10           0.29
# Hw5    43.57   4.67                45                5           1.43
# Exam1  71.13  17.05                75               20           3.87
# Exam2  25.45   8.40                25                8           0.45
# Exam3  44.93   8.65                45                9           0.07
# Exam4  32.34   8.76                35               10           2.66
#
#        abs_std_diff
# Hw1            0.62
# Hw2            0.04
# Hw3            0.49
# Hw4            0.42
# Hw5            0.33
# Exam1          2.95
# Exam2          0.40
# Exam3          0.35
# Exam4          1.24

# %%
df2
# Out:
#      Hw1   Hw2   Hw3   Hw4   Hw5  Exam1  Exam2  Exam3  Exam4
# 0   50.0  81.0  32.0  60.0  50.0   55.0   33.0   44.0   34.0
# 1   39.0  77.0  35.0  53.0  46.0   84.0   28.0   58.0   33.0
# 2   38.0  62.0   7.0  52.0  49.0   60.0   43.0   32.0   35.0
# 3   33.0  98.0  35.0  47.0  47.0   57.0    9.0   42.0   37.0
# 4   46.0  93.0  22.0  42.0  40.0   47.0   11.0   60.0   30.0
# ..   ...   ...   ...   ...   ...    ...    ...    ...    ...
# 95  31.0  50.0  22.0  40.0  45.0   98.0   26.0   45.0   36.0
# 96  37.0  60.0  24.0  48.0  38.0   92.0   34.0   39.0   33.0
# 97  27.0  85.0  18.0  43.0  41.0   76.0   11.0   57.0   25.0
# 98  36.0  72.0  20.0  36.0  50.0   64.0   27.0   38.0   29.0
# 99  39.0  89.0  24.0  31.0  50.0   58.0   13.0   60.0   31.0
#
# [100 rows x 9 columns]

# %%
df2_students = df4

# %%
df2_scores = df2

# %%
max_score = [50, 100, 40, 60, 50, 100, 50, 60, 50]
df2_students['Hw1'] = ((df2_scores['Hw1']/max_score[0])*100).round(2)
df2_students['Hw2'] = ((df2_scores['Hw2']/max_score[1])*100).round(2)
df2_students['Hw3'] = ((df2_scores['Hw3']/max_score[2])*100).round(2)
df2_students['Hw4'] = ((df2_scores['Hw4']/max_score[3])*100).round(2)
df2_students['Hw5'] = ((df2_scores['Hw5']/max_score[4])*100).round(2)
df2_students['Exam1'] = ((df2_scores['Exam1']/max_score[5])*100).round(2)
df2_students['Exam2'] = ((df2_scores['Exam2']/max_score[6])*100).round(2)
df2_students['Exam3'] = ((df2_scores['Exam3']/max_score[7])*100).round(2)
df2_students['Exam4'] = ((df2_scores['Exam4']/max_score[8])*100).round(2)
df2_students.round(2)
# Out:
#    username first_name   last_name    Hw1   Hw2   Hw3     Hw4    Hw5  Exam1  \
# 0    no3732      Norma      Fisher  100.0  81.0  80.0  100.00  100.0   55.0
# 1    jo4264      Jorge    Sullivan   78.0  77.0  87.5   88.33   92.0   84.0
# 2    el5859  Elizabeth       Woods   76.0  62.0  17.5   86.67   98.0   60.0
# 3    su8891      Susan      Wagner   66.0  98.0  87.5   78.33   94.0   57.0
# 4    pe5373      Peter  Montgomery   92.0  93.0  55.0   70.00   80.0   47.0
# ..      ...        ...         ...    ...   ...   ...     ...    ...    ...
# 95   te7922      Terry       Wells   62.0  50.0  55.0   66.67   90.0   98.0
# 96   va5182    Vanessa      Cooper   74.0  60.0  60.0   80.00   76.0   92.0
# 97   mi1307    Michael     Simmons   54.0  85.0  45.0   71.67   82.0   76.0
# 98   ni6302   Nicholas       Kline   72.0  72.0  50.0   60.00  100.0   64.0
# 99   lo2152       Lori     Bennett   78.0  89.0  60.0   51.67  100.0   58.0
#
#     Exam2   Exam3  Exam4
# 0    66.0   73.33   68.0
# ...

# %%
df2_students.to_csv('sample_step4.csv',index = False)

# %%
df_ex4 = pd.read_csv('part2_step4.csv', index = False)
from pandas.testing import assert_frame_equal
assert_frame_equal(df4, df_ex4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26580\2184676029.py in <module>
# ----> 1 df_ex4 = pd.read_csv('part2_step4.csv', index = False)
#       2 from pandas.testing import assert_frame_equal
#       3 assert_frame_equal(df4, df_ex4)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df = pd.read_csv('part2_step5-input.csv')

# %%
df[df.iloc[:,3] == 'AI_ISSUE']
# Out:
# Empty DataFrame
# Columns: [username, first_name, last_name, Hw1, Hw2, Hw3, Hw4, Hw5, Exam1, Exam2, Exam3, Exam4]
# Index: []

# %%
dfhw2 = df[df.iloc[:,4] == 'AI_ISSUE']
dfhw3 = df[df.iloc[:,5] == 'AI_ISSUE']
dfhw4 = df[df.iloc[:,6] == 'AI_ISSUE']
dfhw5 = df[df.iloc[:,7] == 'AI_ISSUE']
dfex1 = df[df.iloc[:,8] == 'AI_ISSUE']
dfex2 = df[df.iloc[:,9] == 'AI_ISSUE']
dfex3 = df[df.iloc[:,10] == 'AI_ISSUE']
dfex4 = df[df.iloc[:,11] == 'AI_ISSUE']
pd5 = pd.concat([dfhw1, dfhw2,dfhw3,dfhw4,dfhw5,dfex1,dfex2,dfex3,dfex4], axis=0)
pd5['index1'] = pd5.index
pd5
# Out:
#    username first_name last_name    Hw1       Hw2       Hw3       Hw4    Hw5  \
# 2    el5859  Elizabeth     Woods   88.0  AI_ISSUE      82.0      73.0   98.0
# 17   bo3163      Bobby    Flores   66.0      73.0  AI_ISSUE      70.0   92.0
# 27   ki1797   Kimberly     Myers   66.0     100.0      68.0  AI_ISSUE   62.0
# 53   ja5187      Jason   Carroll   48.0      63.0      57.0  AI_ISSUE   92.0
# 99   lo2152       Lori   Bennett   78.0      95.0      70.0  AI_ISSUE   90.0
# 7    st4468  Stephanie    Sutton   68.0      64.0      50.0      53.0   90.0
# 31   wh8456    Whitney     Stark   76.0      83.0      55.0      55.0   76.0
# 2    el5859  Elizabeth     Woods   88.0  AI_ISSUE      82.0      73.0   98.0
# 20   ki8877   Kimberly   Maynard   24.0      81.0      45.0      63.0  100.0
# 67   jo9752     Joseph   Freeman   78.0      52.0      65.0      68.0   82.0
# 57   do5420    Douglas     Allen   76.0      59.0      38.0      67.0   68.0
# ...

# %%
pd6 = pd5.groupby(pd5.columns.tolist(),as_index=False).size()
pd6.sort_values(by = 'index1',inplace = True)
pd6 = pd6.rename(columns ={'size':'AI_Count'})
pd6[['username','first_name','last_name','AI_Count']].reset_index(drop = True)
# Out:
#    username first_name last_name  AI_Count
# 0    el5859  Elizabeth     Woods         2
# 1    st4468  Stephanie    Sutton         1
# 2    bo3163      Bobby    Flores         1
# 3    ki8877   Kimberly   Maynard         1
# 4    ki1797   Kimberly     Myers         1
# 5    wh8456    Whitney     Stark         1
# 6    ja5187      Jason   Carroll         1
# 7    do5420    Douglas     Allen         1
# 8    jo9752     Joseph   Freeman         1
# 9    jo3610     Joshua    Carter         1
# 10   mi1307    Michael   Simmons         1
# 11   lo2152       Lori   Bennett         1

# %%
dfhw2 = df[df.iloc[:,4] == 'AI_ISSUE']
dfhw3 = df[df.iloc[:,5] == 'AI_ISSUE']
dfhw4 = df[df.iloc[:,6] == 'AI_ISSUE']
dfhw5 = df[df.iloc[:,7] == 'AI_ISSUE']
dfex1 = df[df.iloc[:,8] == 'AI_ISSUE']
dfex2 = df[df.iloc[:,9] == 'AI_ISSUE']
dfex3 = df[df.iloc[:,10] == 'AI_ISSUE']
dfex4 = df[df.iloc[:,11] == 'AI_ISSUE']
pd5 = pd.concat([dfhw2,dfhw3,dfhw4,dfhw5,dfex1,dfex2,dfex3,dfex4], axis=0)
pd5['index1'] = pd5.index
pd6 = pd5.groupby(pd5.columns.tolist(),as_index=False).size()
pd6.sort_values(by = 'index1',inplace = True)
pd6 = pd6.rename(columns ={'size':'AI_Count'})
pd6[['username','first_name','last_name','AI_Count']].reset_index(drop = True)
# Out:
#    username first_name last_name  AI_Count
# 0    el5859  Elizabeth     Woods         2
# 1    st4468  Stephanie    Sutton         1
# 2    bo3163      Bobby    Flores         1
# 3    ki8877   Kimberly   Maynard         1
# 4    ki1797   Kimberly     Myers         1
# 5    wh8456    Whitney     Stark         1
# 6    ja5187      Jason   Carroll         1
# 7    do5420    Douglas     Allen         1
# 8    jo9752     Joseph   Freeman         1
# 9    jo3610     Joshua    Carter         1
# 10   mi1307    Michael   Simmons         1
# 11   lo2152       Lori   Bennett         1

# %%
df = pd.read_csv('part2_step5-input.csv')

# %%
df
# Out:
#    username first_name   last_name    Hw1       Hw2    Hw3       Hw4    Hw5  \
# 0    no3732      Norma      Fisher  100.0     100.0  100.0     100.0  100.0
# 1    jo4264      Jorge    Sullivan   78.0       NaN   57.0     100.0   78.0
# 2    el5859  Elizabeth       Woods   88.0  AI_ISSUE   82.0      73.0   98.0
# 3    su8891      Susan      Wagner  100.0      90.0   75.0      63.0   94.0
# 4    pe5373      Peter  Montgomery  100.0       NaN   72.0      87.0   72.0
# ..      ...        ...         ...    ...       ...    ...       ...    ...
# 95   te7922      Terry       Wells   82.0      72.0    NaN      62.0   90.0
# 96   va5182    Vanessa      Cooper   70.0      87.0   65.0      90.0   84.0
# 97   mi1307    Michael     Simmons  100.0      87.0   72.0      93.0   84.0
# 98   ni6302   Nicholas       Kline   72.0     100.0   55.0     100.0   80.0
# 99   lo2152       Lori     Bennett   78.0      95.0   70.0  AI_ISSUE   90.0
#
#     Exam1     Exam2     Exam3  Exam4
# ...

# %%
df = df.replace('AI_ISSUE',0)

# %%
df
# Out:
#    username first_name   last_name    Hw1    Hw2    Hw3    Hw4    Hw5  Exam1  \
# 0    no3732      Norma      Fisher  100.0  100.0  100.0  100.0  100.0  100.0
# 1    jo4264      Jorge    Sullivan   78.0    NaN   57.0  100.0   78.0   74.0
# 2    el5859  Elizabeth       Woods   88.0      0   82.0   73.0   98.0   97.0
# 3    su8891      Susan      Wagner  100.0   90.0   75.0   63.0   94.0   70.0
# 4    pe5373      Peter  Montgomery  100.0    NaN   72.0   87.0   72.0   68.0
# ..      ...        ...         ...    ...    ...    ...    ...    ...    ...
# 95   te7922      Terry       Wells   82.0   72.0    NaN   62.0   90.0   83.0
# 96   va5182    Vanessa      Cooper   70.0   87.0   65.0   90.0   84.0   66.0
# 97   mi1307    Michael     Simmons  100.0   87.0   72.0   93.0   84.0   71.0
# 98   ni6302   Nicholas       Kline   72.0  100.0   55.0  100.0   80.0   56.0
# 99   lo2152       Lori     Bennett   78.0   95.0   70.0      0   90.0   71.0
#
#     Exam2  Exam3  Exam4
# ...

# %%
df
# Out:
#    username first_name   last_name    Hw1       Hw2    Hw3       Hw4    Hw5  \
# 0    no3732      Norma      Fisher  100.0     100.0  100.0     100.0  100.0
# 1    jo4264      Jorge    Sullivan   78.0       NaN   57.0     100.0   78.0
# 2    el5859  Elizabeth       Woods   88.0  AI_ISSUE   82.0      73.0   98.0
# 3    su8891      Susan      Wagner  100.0      90.0   75.0      63.0   94.0
# 4    pe5373      Peter  Montgomery  100.0       NaN   72.0      87.0   72.0
# ..      ...        ...         ...    ...       ...    ...       ...    ...
# 95   te7922      Terry       Wells   82.0      72.0    NaN      62.0   90.0
# 96   va5182    Vanessa      Cooper   70.0      87.0   65.0      90.0   84.0
# 97   mi1307    Michael     Simmons  100.0      87.0   72.0      93.0   84.0
# 98   ni6302   Nicholas       Kline   72.0     100.0   55.0     100.0   80.0
# 99   lo2152       Lori     Bennett   78.0      95.0   70.0  AI_ISSUE   90.0
#
#     Exam1     Exam2     Exam3  Exam4
# ...

# %%
df2 = df[['Hw1','Hw2','Hw3','Hw4','Hw5']].fillna(df[['Hw1','Hw2','Hw3','Hw4','Hw5']].mean(axis=1))
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_26580\1002120429.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2 = df[['Hw1','Hw2','Hw3','Hw4','Hw5']].fillna(df[['Hw1','Hw2','Hw3','Hw4','Hw5']].mean(axis=1))

# %%
df2['mean'] = df2.iloc[:, 0:4].mean(axis=1)
df2.dropna()
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_26580\3365996803.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2['mean'] = df2.iloc[:, 0:4].mean(axis=1)
#       Hw1       Hw2    Hw3       Hw4    Hw5   mean
# 0   100.0     100.0  100.0     100.0  100.0  100.0
# 2    88.0  AI_ISSUE   82.0      73.0   98.0   88.0
# 3   100.0      90.0   75.0      63.0   94.0  100.0
# 5    52.0     100.0   35.0      67.0   94.0   52.0
# 6    88.0      69.0   62.0      53.0   98.0   88.0
# ..    ...       ...    ...       ...    ...    ...
# 94   76.0      83.0   60.0      70.0  100.0   76.0
# 96   70.0      87.0   65.0      90.0   84.0   70.0
# 97  100.0      87.0   72.0      93.0   84.0  100.0
# 98   72.0     100.0   55.0     100.0   80.0   72.0
# 99   78.0      95.0   70.0  AI_ISSUE   90.0   78.0
#
# [91 rows x 6 columns]

# %%
df = pd.read_csv('part2_step5-input.csv')

# %%
df
# Out:
#    username first_name   last_name    Hw1       Hw2    Hw3       Hw4    Hw5  \
# 0    no3732      Norma      Fisher  100.0     100.0  100.0     100.0  100.0
# 1    jo4264      Jorge    Sullivan   78.0       NaN   57.0     100.0   78.0
# 2    el5859  Elizabeth       Woods   88.0  AI_ISSUE   82.0      73.0   98.0
# 3    su8891      Susan      Wagner  100.0      90.0   75.0      63.0   94.0
# 4    pe5373      Peter  Montgomery  100.0       NaN   72.0      87.0   72.0
# ..      ...        ...         ...    ...       ...    ...       ...    ...
# 95   te7922      Terry       Wells   82.0      72.0    NaN      62.0   90.0
# 96   va5182    Vanessa      Cooper   70.0      87.0   65.0      90.0   84.0
# 97   mi1307    Michael     Simmons  100.0      87.0   72.0      93.0   84.0
# 98   ni6302   Nicholas       Kline   72.0     100.0   55.0     100.0   80.0
# 99   lo2152       Lori     Bennett   78.0      95.0   70.0  AI_ISSUE   90.0
#
#     Exam1     Exam2     Exam3  Exam4
# ...

# %%
df = df.replace('AI_ISSUE',0)

# %%
df1 = df[['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5'] ]
df1 = df1.astype('float')

# %%
df1 = df1.T.fillna(df1.mean(axis=1)).T.round()
df1
# Out:
#       Hw1    Hw2    Hw3    Hw4    Hw5
# 0   100.0  100.0  100.0  100.0  100.0
# 1    78.0   78.0   57.0  100.0   78.0
# 2    88.0    0.0   82.0   73.0   98.0
# 3   100.0   90.0   75.0   63.0   94.0
# 4   100.0   83.0   72.0   87.0   72.0
# ..    ...    ...    ...    ...    ...
# 95   82.0   72.0   76.0   62.0   90.0
# 96   70.0   87.0   65.0   90.0   84.0
# 97  100.0   87.0   72.0   93.0   84.0
# 98   72.0  100.0   55.0  100.0   80.0
# 99   78.0   95.0   70.0    0.0   90.0
#
# [100 rows x 5 columns]

# %%
df2 = df[['Exam1', 'Exam2', 'Exam3', 'Exam4'] ]
df2 = df2.astype('float')
df2 = df2.T.fillna(df2.mean(axis=1)).T.round()
df2
# Out:
#     Exam1  Exam2  Exam3  Exam4
# 0   100.0  100.0  100.0  100.0
# 1    74.0   56.0   72.0   86.0
# 2    97.0    0.0   63.0   68.0
# 3    70.0   54.0   92.0   62.0
# 4    68.0   78.0   78.0   88.0
# ..    ...    ...    ...    ...
# 95   83.0   68.0   62.0  100.0
# 96   66.0   44.0   77.0   52.0
# 97   71.0   38.0    0.0   40.0
# 98   56.0   54.0   68.0  100.0
# 99   71.0   68.0   63.0   62.0
#
# [100 rows x 4 columns]

# %%
#df = pd.concat([df['username','first_name','last_name'],df1,df2], axis = 1)

# %%
df[['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5']] = df1

# %%
df[['Exam1', 'Exam2', 'Exam3', 'Exam4'] ] = df2

# %%
df
# Out:
#    username first_name   last_name    Hw1    Hw2    Hw3    Hw4    Hw5  Exam1  \
# 0    no3732      Norma      Fisher  100.0  100.0  100.0  100.0  100.0  100.0
# 1    jo4264      Jorge    Sullivan   78.0   78.0   57.0  100.0   78.0   74.0
# 2    el5859  Elizabeth       Woods   88.0    0.0   82.0   73.0   98.0   97.0
# 3    su8891      Susan      Wagner  100.0   90.0   75.0   63.0   94.0   70.0
# 4    pe5373      Peter  Montgomery  100.0   83.0   72.0   87.0   72.0   68.0
# ..      ...        ...         ...    ...    ...    ...    ...    ...    ...
# 95   te7922      Terry       Wells   82.0   72.0   76.0   62.0   90.0   83.0
# 96   va5182    Vanessa      Cooper   70.0   87.0   65.0   90.0   84.0   66.0
# 97   mi1307    Michael     Simmons  100.0   87.0   72.0   93.0   84.0   71.0
# 98   ni6302   Nicholas       Kline   72.0  100.0   55.0  100.0   80.0   56.0
# 99   lo2152       Lori     Bennett   78.0   95.0   70.0    0.0   90.0   71.0
#
#     Exam2  Exam3  Exam4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   username    100 non-null    object
#  1   first_name  100 non-null    object
#  2   last_name   100 non-null    object
#  3   Hw1         100 non-null    float64
#  4   Hw2         100 non-null    float64
#  5   Hw3         100 non-null    float64
#  6   Hw4         100 non-null    float64
#  7   Hw5         100 non-null    float64
#  8   Exam1       100 non-null    float64
#  9   Exam2       100 non-null    float64
#  10  Exam3       100 non-null    float64
#  11  Exam4       100 non-null    float64
# dtypes: float64(9), object(3)
# memory usage: 9.5+ KB

# %%
df.iloc[:,8:11].sum(axis = 1)*.2
# Out:
# 0     60.0
# 1     40.4
# 2     32.0
# 3     43.2
# 4     44.8
#       ...
# 95    42.6
# 96    37.4
# 97    21.8
# 98    35.6
# 99    40.4
# Length: 100, dtype: float64

# %%
df['Grade'] = df.iloc[:,3:8].sum(axis = 1)*.05 + df.iloc[:,8:11].sum(axis = 1)*.2 + df.iloc[:,11]*.15
df = df.round()

# %%
def get_grade(score):
    if score >= 80:
        return 'A'
    elif score >= 70:
        return 'B'
    elif score >= 50:
        return 'C'
    elif score >= 40:
        return 'D'
    else:
        return 'E'

# %%
df['LetterGrade'] = df['Grade'].apply(lambda x: get_grade(x))
df
# Out:
#    username first_name   last_name    Hw1    Hw2    Hw3    Hw4    Hw5  Exam1  \
# 0    no3732      Norma      Fisher  100.0  100.0  100.0  100.0  100.0  100.0
# 1    jo4264      Jorge    Sullivan   78.0   78.0   57.0  100.0   78.0   74.0
# 2    el5859  Elizabeth       Woods   88.0    0.0   82.0   73.0   98.0   97.0
# 3    su8891      Susan      Wagner  100.0   90.0   75.0   63.0   94.0   70.0
# 4    pe5373      Peter  Montgomery  100.0   83.0   72.0   87.0   72.0   68.0
# ..      ...        ...         ...    ...    ...    ...    ...    ...    ...
# 95   te7922      Terry       Wells   82.0   72.0   76.0   62.0   90.0   83.0
# 96   va5182    Vanessa      Cooper   70.0   87.0   65.0   90.0   84.0   66.0
# 97   mi1307    Michael     Simmons  100.0   87.0   72.0   93.0   84.0   71.0
# 98   ni6302   Nicholas       Kline   72.0  100.0   55.0  100.0   80.0   56.0
# 99   lo2152       Lori     Bennett   78.0   95.0   70.0    0.0   90.0   71.0
#
#     Exam2  Exam3  Exam4  Grade LetterGrade
# ...

# %%
names_series = ['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5', 'Exam1', 'Exam2', 'Exam3', 'Exam4', 'Grade']
mean_series = df.describe().T['mean'].round()
mean = dict(zip(names_series, mean_series))
df = df.append(mean, ignore_index = True)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_26580\1767155978.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(mean, ignore_index = True)

# %%
df
# Out:
#     username first_name   last_name    Hw1    Hw2    Hw3    Hw4    Hw5  Exam1  \
# 0     no3732      Norma      Fisher  100.0  100.0  100.0  100.0  100.0  100.0
# 1     jo4264      Jorge    Sullivan   78.0   78.0   57.0  100.0   78.0   74.0
# 2     el5859  Elizabeth       Woods   88.0    0.0   82.0   73.0   98.0   97.0
# 3     su8891      Susan      Wagner  100.0   90.0   75.0   63.0   94.0   70.0
# 4     pe5373      Peter  Montgomery  100.0   83.0   72.0   87.0   72.0   68.0
# ..       ...        ...         ...    ...    ...    ...    ...    ...    ...
# 96    va5182    Vanessa      Cooper   70.0   87.0   65.0   90.0   84.0   66.0
# 97    mi1307    Michael     Simmons  100.0   87.0   72.0   93.0   84.0   71.0
# 98    ni6302   Nicholas       Kline   72.0  100.0   55.0  100.0   80.0   56.0
# 99    lo2152       Lori     Bennett   78.0   95.0   70.0    0.0   90.0   71.0
# 100      NaN        NaN         NaN   70.0   76.0   61.0   69.0   89.0   69.0
#
# ...

# %%
names_series = ['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5', 'Exam1', 'Exam2', 'Exam3', 'Exam4', 'Grade']
std_deviation = df.describe().T['std'].round()
std_deviation = dict(zip(names_series, std_deviation))
df = df.append(std_deviation, ignore_index = True)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_26580\3099491048.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(std_deviation, ignore_index = True)

# %%
# Out:
#               Hw1         Hw2         Hw3         Hw4         Hw5       Exam1  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean    69.882353   75.049020   60.598039   68.872549   87.980392   68.823529
# std     18.195470   17.088806   18.295842   19.769299   12.294231   22.506066
# min     18.000000    0.000000    0.000000    0.000000    9.000000    0.000000
# 25%     58.000000   64.250000   52.000000   60.500000   82.500000   57.000000
# 50%     71.000000   76.000000   60.500000   70.000000   90.000000   71.000000
# 75%     83.500000   87.000000   72.000000   82.250000   97.500000   84.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#             Exam2       Exam3       Exam4       Grade
# count  102.000000  102.000000  102.000000  102.000000
# mean    47.323529   70.656863   68.294118   65.637255
# std     18.821287   19.265984   17.897723   10.101259
# ...

# %%
df2 = df

# %%
df2.rename({100: "mean", 101: "std"}, inplace = True)
df2
# Out:
#      username first_name   last_name    Hw1    Hw2    Hw3    Hw4    Hw5  \
# 0      no3732      Norma      Fisher  100.0  100.0  100.0  100.0  100.0
# 1      jo4264      Jorge    Sullivan   78.0   78.0   57.0  100.0   78.0
# 2      el5859  Elizabeth       Woods   88.0    0.0   82.0   73.0   98.0
# 3      su8891      Susan      Wagner  100.0   90.0   75.0   63.0   94.0
# 4      pe5373      Peter  Montgomery  100.0   83.0   72.0   87.0   72.0
# ...       ...        ...         ...    ...    ...    ...    ...    ...
# 97     mi1307    Michael     Simmons  100.0   87.0   72.0   93.0   84.0
# 98     ni6302   Nicholas       Kline   72.0  100.0   55.0  100.0   80.0
# 99     lo2152       Lori     Bennett   78.0   95.0   70.0    0.0   90.0
# mean      NaN        NaN         NaN   70.0   76.0   61.0   69.0   89.0
# std       NaN        NaN         NaN   18.0   16.0   18.0   19.0    9.0
#
#       Exam1  Exam2  Exam3  Exam4  Grade LetterGrade
# ...

# %%
df2.index = df2.index.astype(str)

# %%
df_ex6 = pd.read_csv('part2_step6.csv', index_col  = 0)
from pandas.testing import assert_frame_equal
assert_frame_equal(df, df_ex6)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26580\366285548.py in <module>
#       1 df_ex6 = pd.read_csv('part2_step6.csv', index_col  = 0)
#       2 from pandas.testing import assert_frame_equal
# ----> 3 assert_frame_equal(df, df_ex6)
#
#     [... skipping hidden 2 frame]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\testing.pyx in pandas._libs.testing.assert_almost_equal()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\testing.pyx in pandas._libs.testing.assert_almost_equal()
#
# ~\anaconda3\lib\site-packages\pandas\_testing\asserters.py in raise_assert_detail(obj, message, left, right, diff, index_values)
#     680         msg += f"\n[diff]: {diff}"
#     681
# --> 682     raise AssertionError(msg)
#     683
#     684
#
# AssertionError: DataFrame.iloc[:, 7] (column name="Hw5") are different
#
# ...

# %%
df_ex6
# Out:
#      username first_name   last_name    Hw1    Hw2    Hw3    Hw4    Hw5  \
# 0      no3732      Norma      Fisher  100.0  100.0  100.0  100.0  100.0
# 1      jo4264      Jorge    Sullivan   78.0   78.0   57.0  100.0   78.0
# 2      el5859  Elizabeth       Woods   88.0    0.0   82.0   73.0   98.0
# 3      su8891      Susan      Wagner  100.0   90.0   75.0   63.0   94.0
# 4      pe5373      Peter  Montgomery  100.0   83.0   72.0   87.0   72.0
# ...       ...        ...         ...    ...    ...    ...    ...    ...
# 97     mi1307    Michael     Simmons  100.0   87.0   72.0   93.0   84.0
# 98     ni6302   Nicholas       Kline   72.0  100.0   55.0  100.0   80.0
# 99     lo2152       Lori     Bennett   78.0   95.0   70.0    0.0   90.0
# mean      NaN        NaN         NaN   70.0   76.0   61.0   69.0   89.0
# std       NaN        NaN         NaN   18.0   16.0   18.0   19.0   10.0
#
#       Exam1  Exam2  Exam3  Exam4  Grade LetterGrade
# ...

# %%
df = pd.read_csv('part2_step5-input.csv')
df = df.replace('AI_ISSUE',0)
df1 = df[['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5'] ]
df1 = df1.astype('float')
df1 = df1.T.fillna(df1.mean(axis=1)).T.round()
df2 = df[['Exam1', 'Exam2', 'Exam3', 'Exam4'] ]
df2 = df2.astype('float')
df2 = df2.T.fillna(df2.mean(axis=1)).T.round()
df[['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5']] = df1
df[['Exam1', 'Exam2', 'Exam3', 'Exam4'] ] = df2
df['Grade'] = df.iloc[:,3:8].sum(axis = 1)*.05 + df.iloc[:,8:11].sum(axis = 1)*.2 + df.iloc[:,11]*.15
df = df.round()
def get_grade(score):
    if score >= 80:
        return 'A'
    elif score >= 70:
        return 'B'
    elif score >= 50:
        return 'C'
    elif score >= 40:
        return 'D'
    else:
        return 'E'
df['LetterGrade'] = df['Grade'].apply(lambda x: get_grade(x))
names_series = ['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5', 'Exam1', 'Exam2', 'Exam3', 'Exam4', 'Grade']
mean_series = df.describe().T['mean'].round()
mean = dict(zip(names_series, mean_series))
df = df.append(mean, ignore_index = True)
names_series = ['Hw1', 'Hw2', 'Hw3', 'Hw4', 'Hw5', 'Exam1', 'Exam2', 'Exam3', 'Exam4', 'Grade']
std_deviation = df.iloc[0:-1,:].describe().T['std'].round()
std_deviation = dict(zip(names_series, std_deviation))
df = df.append(std_deviation, ignore_index = True)
df.rename({100: "mean", 101: "std"}, inplace = True)
df.index = df.index.astype(str)
df
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_26580\3443860320.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(mean, ignore_index = True)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_26580\3443860320.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(std_deviation, ignore_index = True)
#      username first_name   last_name    Hw1    Hw2    Hw3    Hw4    Hw5  \
# 0      no3732      Norma      Fisher  100.0  100.0  100.0  100.0  100.0
# 1      jo4264      Jorge    Sullivan   78.0   78.0   57.0  100.0   78.0
# 2      el5859  Elizabeth       Woods   88.0    0.0   82.0   73.0   98.0
# 3      su8891      Susan      Wagner  100.0   90.0   75.0   63.0   94.0
# 4      pe5373      Peter  Montgomery  100.0   83.0   72.0   87.0   72.0
# ...

# %%
from pandas.testing import assert_frame_equal
assert_frame_equal(df, df_ex6)
